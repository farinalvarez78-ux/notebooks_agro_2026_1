# %% [markdown]
# <a href="https://colab.research.google.com/github/farinalvarez78-ux/notebooks_agro_2026_1/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
# $$pa= l*0.92$$
# $$r =(pa/pr) *100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float).(pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("Ingrese el nombre del lote de producción: ")
pr= float(input("Ingrese el peso de los racimos en kg: "))
lt= float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
pa= lt*0.92
r= (pa/pr)*100

# SALIDA : informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote de producción: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# ```markdown
# Aquí está la explicación línea por línea del código proporcionado:
#
# *   `nombre = input("Ingrese el nombre del lote de producción: ")`
#     *   Esta línea solicita al usuario que ingrese el nombre del lote de producción. El texto dentro de las comillas (`"Ingrese el nombre del lote de producción: "`) es el mensaje que se muestra al usuario. La entrada del usuario se almacena como una cadena (string) en la variable `nombre`.
#
# *   `pr= float(input("Ingrese el peso de los racimos en kg: "))`
#     *   Similar a la línea anterior, esta línea solicita al usuario el peso de los racimos en kilogramos. La función `input()` lee la entrada del usuario como una cadena. La función `float()` convierte esta cadena a un número decimal (punto flotante), ya que el peso puede tener decimales. Este valor se guarda en la variable `pr`.
#
# *   `lt= float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))`
#     *   Esta línea solicita la cantidad de aceite crudo obtenido en litros. De nuevo, `input()` obtiene la entrada como cadena y `float()` la convierte a un número decimal (flotante), guardándolo en la variable `lt`.
#
# *   `pa= lt*0.92`
#     *   Esta línea realiza el cálculo del peso del aceite. Multiplica la cantidad de litros de aceite (`lt`) por su densidad aproximada (0.92 kg/L). El resultado, que es el peso del aceite en kilogramos, se almacena en la variable `pa`.
#
# *   `r= (pa/pr)*100`
#     *   Esta línea calcula el Índice de Rendimiento de Extracción (IRE). Divide el peso del aceite (`pa`) por el peso total de los racimos (`pr`), y luego multiplica el resultado por 100 para expresarlo como un porcentaje. El rendimiento calculado se guarda en la variable `r`.
#
# *   `print("El rendimiento del lote", nombre, "es del", r, "%")`
#     *   Esta es la línea de salida que muestra el resultado al usuario. Utiliza la función `print()` para concatenar varias cadenas y variables. Muestra un mensaje que incluye el nombre del lote (`nombre`), el rendimiento calculado (`r`), y el símbolo de porcentaje (`%`), informando el resultado final de una manera legible.
# ```
